# %%
import time
from pymysql import *
import pandas as pd
import numpy as np
import datetime

# %%
conn = connect(
    host = '127.0.0.1',
    user = 'root',
    password = 'gky308219',
    db = 'paper_web',
    port = 3306,
    charset = 'utf8'
)

# %%
cs = conn.cursor()
s = "select id from db_source_detail_info where source_name=%s"
cs.execute(s, test)
# Out:
# 1

# %%
d = cs.fetchall()

# %%
d[0][0]
# Out:
# 5

# %%
source_type = data.loc[5]['Publication Type']
test = data.loc[5]['Source Title'] if source_type != 'C' else data.loc[5]['Conference Title']
test
# Out:
# 'PLATING AND SURFACE FINISHING'

# %%
sql = "insert into db_source_detail_info values (null, %s, %s, %s, %s, %s, %s, %s, %s, %s, 1, %s)"

# %%
val = (source_name, source_type, source_date, source_location, source_publisher, source_issn, source_eissn, source_isbn, source_abbreviation, edit_date)

# %%
data = pd.read_excel('1 (1).xls', sheet_name='savedrecs', keep_default_na=False)

# %%
source_type = data.loc[0]['Publication Type']
source_name = data.loc[0]['Source Title'] if source_type != 'C' else data.loc[0]['Conference Title']
source_date = ' ' if len(data.loc[0]['Conference Date']) == 0 else data.loc[0]['Conference Date']
source_location = data.loc[0]['Conference Location'] if source_type == 'C' else data.loc[0]['Addresses']
source_location = ' '.join(source_location.split(','))
source_publisher = ' '.join(data.loc[0]['Publisher'].split(','))
source_issn = data.loc[0]['ISSN']
source_eissn = data.loc[0]['eISSN']
source_isbn = data.loc[0]['ISBN']
source_abbreviation = data.loc[0]['Journal Abbreviation']
edit_date = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')

# %%
source_type
# Out:
# 'J'

# %%
# 导入期刊数据
sql = "insert into db_source_detail_info values (null, %s, %s, %s, %s, %s, %s, %s, %s, %s, 1, %s)"
for i in range(len(data)):
    source_type = data.loc[i]['Publication Type']
    source_name = data.loc[i]['Source Title'] if source_type != 'C' else data.loc[i]['Conference Title']
    source_date = data.loc[i]['Conference Date']
    source_location = data.loc[i]['Conference Location'] if source_type == 'C' else data.loc[i]['Addresses']
    source_publisher = data.loc[i]['Publisher']
    source_issn = data.loc[i]['ISSN']
    source_eissn = data.loc[i]['eISSN']
    source_isbn = data.loc[i]['ISBN']
    source_abbreviation = data.loc[i]['Journal Abbreviation']
    edit_date = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    
    val = (source_name, source_type, source_date, source_location, source_publisher, source_issn, source_eissn, source_isbn, source_abbreviation, edit_date)
    cs = conn.cursor()
    try:
        cs.execute(sql, val)
    except Exception as e:
        print('插入SourceDetailInfo',e)
    
    conn.commit()
# Out:
# 插入SourceDetailInfo (1062, "Duplicate entry 'CORROSION' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'TRANSACTIONS OF THE INDIAN INSTITUTE OF METALS' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'PLATING AND SURFACE FINISHING' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'TETSU TO HAGANE-JOURNAL OF THE IRON AND STEEL INSTITUTE OF JAPAN' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'BRITISH CORROSION JOURNAL' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'PLATING AND SURFACE FINISHING' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'JOURNAL OF PRESSURE VESSEL TECHNOLOGY-TRANSACTIONS OF THE ASME' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'CORROSION SCIENCE' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry '27th Annual International Electronics Manufacturing Technology S' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'EDN' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'PLATING AND SURFACE FINISHING' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'PLATING AND SURFACE FINISHING' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'MATERIALS ENGINEERING' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'CORROSION' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'CORROSION SCIENCE' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'CANADIAN MINING JOURNAL' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'MATERIALS PERFORMANCE' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'CORROSION' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry '50th Electronic Components & Technology Conference (ECTC 01)' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry '3RD INTERNATIONAL CONF ON PRACTICAL APPLICATIONS OF RESIDUAL STR' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'ISOTOPENPRAXIS' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'CORROSION' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'JOURNAL OF ELECTROANALYTICAL CHEMISTRY' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'PLATING AND SURFACE FINISHING' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'BULLETIN OF THE JSME-JAPAN SOCIETY OF MECHANICAL ENGINEERS' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'CORROSION SCIENCE' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'TRANSACTIONS OF THE IRON AND STEEL INSTITUTE OF JAPAN' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'CORROSION' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'MATERIALS PERFORMANCE' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'ADVANCED MATERIALS & PROCESSES' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'JOURNAL OF METALS' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 
INISHING' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'BULLETIN OF ENVIRONMENTAL CONTAMINATION AND TOXICOLOGY' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'WERKSTOFFE UND KORROSION-MATERIALS AND CORROSION' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry '10th Solid Freeform Fabrication Symposium (SFF)' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'DESALINATION' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'MATERIALS AND MANUFACTURING PROCESSES' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'STEEL RESEARCH' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'International Symposium on Environmentally Assisted Cracking: Pr' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'PROTECTION OF METALS' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'JOURNAL OF MATERIALS ENGINEERING AND PERFORMANCE' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'WEAR' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'INTERNATIONAL JOURNAL OF ADHESION AND ADHESIVES' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry '17th International Cryogenic Engineering Conference' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'JOURNAL OF MICROMECHANICS AND MICROENGINEERING' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'ELECTROCHIMICA ACTA' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'CORROSION SCIENCE' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'JOURNAL OF THE JAPAN INSTITUTE OF METALS' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'PUBLIC WORKS' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'MATERIALS SCIENCE AND ENGINEERING A-STRUCTURAL MATERIALS PROPERT' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'REVUE DE METALLURGIE-CAHIERS D INFORMATIONS TECHNIQUES' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'METALLURGICAL TRANSACTIONS A-PHYSICAL METALLURGY AND MATERIALS S' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'CORROSION' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'ELECTROCHEMICAL METHODS IN CORROSION RESEARCH VI, PTS 1 AND 2' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'CORROSION SCIENCE' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry '29th IEEE Photovoltaic Specialists Conference' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'TRANSACTIONS OF NONFERROUS METALS SOCIETY OF CHINA' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'TRANSACTIONS OF THE INSTITUTE OF METAL FINISHING' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'MATERIALS SCIENCE & ENGINEERING C-BIOMIMETIC AND SUPRAMOLECULAR ' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'MAGNESIUM ALLOYS 2000' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'JOURNAL OF THE ELECTROCHEMICAL SOCIETY' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'CORROSION SCIENCE' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'RUSSIAN JOURNAL OF APPLIED CHEMISTRY' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'JOURNAL OF THE AUSTRALASIAN INSTITUTE OF METALS' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'LUBRICATION ENGINEERING' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'CORROSION SCIENCE' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'WERKSTOFFE UND KORROSION-MATERIALS AND CORROSION' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'CHEMISTRY & INDUSTRY' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'ENGINEERING NEWS-RECORD' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'JOURNAL OF APPLIED PHYSICS' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'JOURNAL OF THE ELECTROCHEMICAL SOCIETY' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'JOURNAL OF THE ELECTROCHEMICAL SOCIETY' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'MATERIALS PERFORMANCE' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'CORROSION' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'BOLETIN DE LA SOCIEDAD ESPANOLA DE CERAMICA Y VIDRIO' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'ELECTROCHEMISTRY' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'CORROSION' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'JOURNAL OF NUCLEAR MATERIALS' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'RELIABILITY ENGINEERING & SYSTEM SAFETY' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'MATERIALS SCIENCE AND ENGINEERING A-STRUCTURAL MATERIALS PROPERT' for key 'db_source_detail_info.source_name'")
# 插入SourceDetailInfo (1062, "Duplicate entry 'International Symposium on Environmentally Assisted Cracking: Pr' for key 'db_source_detail_info.source_name'")

# %%
# 导入文章数据
sql = "insert into db_paper_main_info values(null, %s, %s, %s, %s, %s, %s, 1, %s, %s)"
sel = "select id from db_source_detail_info where source_name=%s"
for i in range(len(data)):
    source_type = data.loc[i]['Publication Type']
    source_name = data.loc[i]['Source Title'] if source_type != 'C' else data.loc[i]['Conference Title']
    
    cs = conn.cursor()
    cs.execute(sel, source_name)
    try:
        temp = cs.fetchall()[0][0]
        paper_title = data.loc[i]['Article Title']
        paper_author = data.loc[i]['Author Full Names']
        paper_publish_year = data.loc[i]['Publication Year']
        paper_keywords = data.loc[i]['Author Keywords']
        paper_abstract = data.loc[i]['Abstract']
        paper_affiliations = data.loc[i]['Affiliations']
        edit_date = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')

        val = (paper_title, paper_author, paper_publish_year, paper_keywords, paper_abstract, paper_affiliations, edit_date, str(temp))

        try:
            cs.execute(sql, val)
        except Exception as e:
            print('插入MainInfo', e)
    except Exception as e:
        print('检索不到期刊:',source_name)


    conn.commit()

# %%
# 导入其他数据
sql_detail = "insert into db_paper_detail_info values(null, %s, %s, %s, %s, %s, %s, %s, 1, %s, %s)"
sql_cited = "insert into db_paper_cited_count values(null, %s, %s, 1, %s, %s)"
sql_download = "insert into db_paper_download_count values(null, 0, 1, %s, %s)"
sql_file = "insert into db_paper_file_path values(null, null, 1, %s, %s)"
sel = "select id from db_paper_main_info where paper_title=%s and paper_publish_year"

for i in range(len(data)):
    paper_title = data.loc[i]['Article Title']
    paper_publish_year = data.loc[i]['Publication Year']
    cs = conn.cursor()
    val = (paper_title, str(paper_publish_year))
    cs.execute(sel, val)
    
    try:
        temp = cs.fetchall()[0][0]
        
        paper_language = data.loc[i]['Language']
        paper_volume = data.loc[i]['Volume']
        paper_issue = data.loc[i]['Issue']
        paper_start_page = data.loc[i]['Start Page']
        paper_end_page = data.loc[i]['End Page']
        paper_page = str(paper_start_page) + '-' + str(paper_end_page)
        paper_doi = data.loc[i]['DOI']
        paper_ids = data.loc[i]['IDS Number']
        paper_wos = data.loc[i]['UT (Unique WOS ID)']
        
        cited_reference_count = data.loc[i]['Cited Reference Count']
        cited_times = data.loc[i]['Times Cited, All Databases']
        
        edit_date = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        
        val_detail = (paper_language, paper_volume, paper_issue, paper_page, paper_doi, paper_ids, paper_wos, edit_date, str(temp))
        val_cited = (int(cited_reference_count), int(cited_times), edit_date, str(temp))
        val_download = (edit_date, str(temp))
        val_file = (edit_date, str(temp))
        
        try:
            cs.execute(sql_detail, val_detail)
        except Exception as e:
            print('插入Detail', e)
        try:
            cs.execute(sql_cited, val_cited)
        except Exception as e:
            print('插入Cited', e)
        try:
            cs.execute(sql_download, val_download)
        except Exception as e:
            print('插入Download', e)
        try:
            cs.execute(sql_file, val_file)
        except Exception as e:
            print('插入File', e)
    except Exception as e:
        print('文章没有存入数据库：',paper_title)
        
    conn.commit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 13
#      11 cs = conn.cursor()
#      12 val = (paper_title, str(paper_publish_year))
# ---> 13 cs.execute(sel, val)
#      15 try:
#      16     temp = cs.fetchall()[0][0]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymysql\cursors.py:151, in Cursor.execute(self, query, args)
#     148 while self.nextset():
#     149     pass
# --> 151 query = self.mogrify(query, args)
#     153 result = self._query(query)
#     154 self._executed = query
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymysql\cursors.py:129, in Cursor.mogrify(self, query, args)
#     126 conn = self._get_db()
#     128 if args is not None:
# --> 129     query = query % self._escape_args(args, conn)
#     131 return query
#
# TypeError: not all arguments converted during string formatting

# %%
cs = conn.cursor()
try: 
    cs.execute(sql)
except Exception as e:
    print('插入source',e)

# %%
source_id = cs.execute(f'select id from db_source_detail_info where source_name="{source_name}"')

# %%
source_id
# Out:
# 0

# %%
for i in range(len(data)):
    source_type = data.loc[i]['Publication Type']
    source_name = data.loc[i]['Source Title'] if source_type != 'C' else data.loc[i]['Conference Title']
    source_date = data.loc[i]['Conference Date']
    source_location = data.loc[i]['Conference Location'] if source_type == 'C' else data.loc[i]['Addresses']
    source_publisher = data.loc[i]['Publisher']
    source_issn = data.loc[i]['ISSN']
    source_eissn = data.loc[i]['eISSN']
    source_isbn = data.loc[i]['ISBN']
    source_abbreviation = data.loc[i]['Journal Abbreviation']

    cs = conn.cursor()
    try:
        sql = f'insert into paper_sourcedetailinfomodel(source_name,source_type,source_date,source_location,source_publisher_source_issn,source_eissn,source_isbn,source_abbrevation) values({source_name},{source_type},{source_date},{source_location},{source_publisher},{source_issn},{source_eissn},{source_isbn},{source_abbreviation}'
        cs.execute(sql)
    except Exception as e:
        print('插入source',e)
    source_id = cs.execute(f'select source_id from paper_sourcedetailinfomodel where source_name={source_name}').fetchall()

    paper_title = data.loc[i]['Article Title']
    paper_author = data.loc[i]['Author Full Names']
    paper_publish_year = data.loc[i]['Publication Year']
    paper_keywords = data.loc[i]['Author Keywords']
    paper_abstract = data.loc[i]['Abstract']
    paper_affiliations = data.loc[i]['Affiliations']

    try:
        sql = f'insert into paper_papermaininfomodel(paper_title,paper_author,paper_publisher_year,paper_keywords,paper_abstract,paper_affiliations,paper_source_id) values({paper_title},{paper_author},{paper_publish_year},{paper_keywords},{paper_abstract},{paper_affiliations},{source_id})'
        cs.execute('插入MainInfo',sql)
    except Exception as e:
        print(e)
    paper_id = cs.execute(f'select paper_id from paper_papermaininfomodel where paper_title={paper_title}').fetchall()[0]

    paper_language = data.loc[i]['Language']
    paper_volume = data.loc[i]['Volume']
    paper_issue = data.loc[i]['Issue']
    paper_start_page = data.loc[i]['Start Page']
    paper_end_page = data.loc[i]['End Page']
    paper_page = str(paper_start_page) + str(paper_end_page)
    paper_doi = data.loc[i]['DOI']
    paper_ids = data.loc[i]['IDS Number']
    paper_wos = data.loc[i]['UT (Unique WOS ID)']


    try: 
        sql = f'insert into paper_paperdetailinfomodel(paper_language,paper_volume,paper_issue,paper_page,paper_doi,paper_ids,paper_wos,paper_id_id) values({paper_language},{paper_volume},{paper_issue},{paper_page},{paper_doi},{paper_ids},{paper_wos},{paper_id})'
        cs.execute(sql)
    except Exception as e:
        print('插入DetailInfo',e)

    cited_reference_count = data.loc[i]['Cited Reference Count']
    cited_times = data.loc[i]['Times Cited, All Databases']
    try:
        sql = f'insert into paper_papercitedcountmodel(cited_reference_count,cited_times,paper_id_id) values({cited_reference_count},{cited_times},{paper_id})'
        cs.exceute(sql)
    except Exception as e:
        print('插入CitedCount',e)
    
    try:
        cs.exceute(f'insert into paper_paperdownloadcountmodel(paper_id_id) values({paper_id})')
        cs.exceute(f'insert into paper_paperfilepathmodel(paper_id_id) values({paper_id})')
    except Exception as e:
        print('最后两个',e)

# %%
B = insert(conn, data)

# %%
for i in range(len(data)):
    print('当前出版商：',data.loc[i]['Publisher'], '\n')

# %%
len(data)

# %%
def GetInfo(data):
    for itme in data:
        
    source_name = data['']
    source_type = data['']
    source_date = data['']
    source_location = data['']
    source_publisher = data['']
    source_issn = data['']
    source_eissn = data['']
    source_isbn = data['']
    source_abbreviation = data['']
    
    paper_title = data['']
    paper_author = data['']
    paper_publish_year = ['']
    paper_keywords = data['']
    paper_abstract = data['']
    paper_affiliations = data['']
    
    paper_language = data['']
    paper_volume = data['']
    paper_issue = data['']
    paper_page = data['']
    paper_doi = data['']
    paper_ids = data['']
    paper_wos = data['']
    
    cited_reference_count = data['']
    cited_times = data['']

# %%
1 == 1

# %%
1 != 2

# %%
1 <> 2

# %%
1 ~= 2

# %%
time.time()
